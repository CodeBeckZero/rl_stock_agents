# %%
"Tabular Q"
import sys
pwd = "P:/dsv/DAMII/Practical Project/rl_stock_agents"
sys.path.append(pwd)

import cleandata
import numpy as np
import matplotlib.pyplot as plt
from agents import Discrete_QtabAgent

from agentperform import agent_stock_performance


stock_list =["amzn_daily.csv", "appl_daily.csv","tsla_daily.csv","f_daily.csv",
             "pfe_daily.csv", "coke_daily.csv","brk_daily.csv","nee_daily.csv",
             "jnj_daily.csv","pg_daily.csv"]

stock_name_list = ['AMZN','APPL','TSLA','F','PFE','COKE','BRK','NEE','JNJ','PG']

import_path = "P:/dsv/DAMII/Practical Project/rl_stock_agents/input_data"

ohlcv_bin_sizes = [150,30,30,150,150]
training_range = [[0,2000]]
test_range = [[2000,2516]]
epochs = 250




for file_name, stock_name in zip(stock_list,stock_name_list):
    
    # Import File
    df_ohlcv = cleandata.NASDAQ_csv_input(file_name,import_path)


    agent = Discrete_QtabAgent(df_ohlcv,
                      ohlcv_bin_sizes,
                      training_range, 
                      epochs,
                      test_range)
    

    for start_idx, end_idx in training_range:
        
        agent.train(start_idx,end_idx,initial_epsilon = 0.75, final_epsilon = 0.1)

    
    
    for start_idx, end_idx in test_range:
        
        agent.test(start_idx,end_idx)
    
    trades_list = [entry['Action'] for entry in agent.env.step_info]
    
    trade_seq = np.array(trades_list)
    
    test_result = agent_stock_performance(df_ohlcv['close']\
                    .iloc[test_range[0][0]:test_range[0][1]].to_numpy(),\
                    trade_seq,stock_name,"Q-Tabular", display_graph=False)

    display(test_result)
# Out:
# {'stock': 'AMZN',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 27,
#  'n_wins': 14,
#  'n_losses': 13,
#  'win_percentage': 51.85185185185185,
#  'cumulative_return': 1.0887431880761325,
#  'sortino': 3.5117954952099737,
#  'max_drawdown': -9.92471429988111,
#  'sharpe': 1.8456215859913923,
#  'trade_dur_avg': 1.1481481481481481,
#  'trade_dur_min': 1,
#  'trade_dur_max': 2,
#  'buy_hold': 0.8704685566366558}
# {'stock': 'APPL',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 30,
#  'n_wins': 15,
#  'n_losses': 15,
#  'win_percentage': 50.0,
#  'cumulative_return': 0.9434413042947989,
#  'sortino': -1.5311419555117096,
#  'max_drawdown': -15.364510112740371,
#  'sharpe': -1.2416817578373267,
#  'trade_dur_avg': 1.0666666666666667,
#  'trade_dur_min': 1,
#  'trade_dur_max': 2,
#  'buy_hold': 1.1032099611606123}
# {'stock': 'TSLA',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 34,
#  'n_wins': 20,
#  'n_losses': 14,
#  'win_percentage': 58.82352941176471,
#  'cumulative_return': 0.9864720457876033,
#  'sortino': 0.34149362596955846,
#  'max_drawdown': -20.878700603279466,
#  'sharpe': 0.23646546352257808,
#  'trade_dur_avg': 1.0294117647058822,
#  'trade_dur_min': 1,
#  'trade_dur_max': 2,
#  'buy_hold': 0.7337224966322407}
# {'stock': 'F',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 42,
#  'n_wins': 20,
#  'n_losses': 22,
#  'win_percentage': 47.61904761904761,
#  'cumulative_return': 1.1256213258979455,
#  'sortino': 3.663569040245052,
#  'max_drawdown': -7.2573453966548795,
#  'sharpe': 2.143241361651979,
#  'trade_dur_avg': 1.1904761904761905,
#  'trade_dur_min': 1,
#  'trade_dur_max': 4,
#  'buy_hold': 0.6254416961130743}
# {'stock': 'PFE',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 36,
#  'n_wins': 15,
#  'n_losses': 21,
#  'win_percentage': 41.66666666666667,
#  'cumulative_return': 0.9463212369739898,
#  'sortino': -1.9861654357218694,
#  'max_drawdown': -10.506011007169658,
#  'sharpe': -1.3291475632976124,
#  'trade_dur_avg': 1.2222222222222223,
#  'trade_dur_min': 1,
#  'trade_dur_max': 5,
#  'buy_hold': 0.5566147859922179}
# {'stock': 'COKE',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 32,
#  'n_wins': 15,
#  'n_losses': 17,
#  'win_percentage': 46.875,
#  'cumulative_return': 1.1804570773385479,
#  'sortino': 9.335776215061333,
#  'max_drawdown': -4.128436167662275,
#  'sharpe': 4.185081199870833,
#  'trade_dur_avg': 1.15625,
#  'trade_dur_min': 1,
#  'trade_dur_max': 3,
#  'buy_hold': 1.7169633810971197}
# {'stock': 'BRK',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 26,
#  'n_wins': 13,
#  'n_losses': 13,
#  'win_percentage': 50.0,
#  'cumulative_return': 0.9760905730473577,
#  'sortino': -1.531293442540868,
#  'max_drawdown': -7.193727103026781,
#  'sharpe': -1.1809174611536526,
#  'trade_dur_avg': 1.0,
#  'trade_dur_min': 1,
#  'trade_dur_max': 1,
#  'buy_hold': 1.2722125384588387}
# {'stock': 'NEE',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 31,
#  'n_wins': 15,
#  'n_losses': 16,
#  'win_percentage': 48.38709677419355,
#  'cumulative_return': 0.9438502896164013,
#  'sortino': -1.9121356744184748,
#  'max_drawdown': -9.341179789168619,
#  'sharpe': -1.4942992476105237,
#  'trade_dur_avg': 1.0,
#  'trade_dur_min': 1,
#  'trade_dur_max': 1,
#  'buy_hold': 0.670726306465899}
# {'stock': 'JNJ',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 38,
#  'n_wins': 19,
#  'n_losses': 19,
#  'win_percentage': 50.0,
#  'cumulative_return': 1.0574985719564147,
#  'sortino': 5.588035369766934,
#  'max_drawdown': -1.8715590273053473,
#  'sharpe': 2.9851804682753422,
#  'trade_dur_avg': 1.0789473684210527,
#  'trade_dur_min': 1,
#  'trade_dur_max': 2,
#  'buy_hold': 0.9513812827065838}
# {'stock': 'PG',
#  'agent_name': 'Q-Tabular',
#  'n_trades': 41,
#  'n_wins': 15,
#  'n_losses': 26,
#  'win_percentage': 36.58536585365854,
#  'cumulative_return': 0.9650383827803095,
#  'sortino': -1.8207473914982997,
#  'max_drawdown': -4.670078491691521,
#  'sharpe': -1.174731655334117,
#  'trade_dur_avg': 1.1219512195121952,
#  'trade_dur_min': 1,
#  'trade_dur_max': 2,
#  'buy_hold': 0.9582103260513022}
